# %%
# %load_ext kedro.ipython
# %reload_kedro
# Out:
# The kedro.ipython extension is already loaded. To reload it, use:
#   %reload_ext kedro.ipython
# [01/17/26 19:34:42] INFO     Resolved project path as:                                              ]8;id=827611;file://C:\Users\cooba\Desktop\SUML_praca_koncowa\SUML_projekt\venv\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=667575;file://C:\Users\cooba\Desktop\SUML_praca_koncowa\SUML_projekt\venv\Lib\site-packages\kedro\ipython\__init__.py#181\181]8;;\
#                              C:\Users\cooba\Desktop\SUML_praca_koncowa\SUML_projekt.
#                              To set a different path, run '%reload_kedro <project_root>'
# ...

# %%
df = catalog.load("X_train")
# Out:
# [01/17/26 19:38:36] INFO     Loading data from X_train (CSVDataset)...                         ]8;id=125605;file://C:\Users\cooba\Desktop\SUML_praca_koncowa\SUML_projekt\venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=5578;file://C:\Users\cooba\Desktop\SUML_praca_koncowa\SUML_projekt\venv\Lib\site-packages\kedro\io\data_catalog.py#1048\1048]8;;\

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
df.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    Location   MinTemp   MaxTemp  Rainfall  WindGustDir  WindGustSpeed  \
# 0         2  0.425663  0.574075 -0.274208           10       0.084609
# 1        18 -1.089759 -1.184181 -0.274208            3       0.084609
# 2        42 -1.558447 -0.382417 -0.274208            1      -1.059787
# 3         9 -1.777167 -1.085719 -0.274208           12      -1.899011
# 4        15  0.472531  0.292754 -0.274208           11       0.084609
#
#    WindDir9am  WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# 0          10           9      0.683707     -0.648508    -0.996614
# 1           3           6      0.683707      0.615330     0.219390
# 2           1          10     -0.790588     -1.452768     0.695218
# 3           3          15     -1.584440     -1.452768     1.541135
# 4           6           2      0.683707      0.155753    -0.520786
#
# ...
