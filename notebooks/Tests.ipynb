# %%
# %load_ext kedro.ipython
# %reload_kedro
# Out:
# The kedro.ipython extension is already loaded. To reload it, use:
#   %reload_ext kedro.ipython
#                     INFO     Resolved project path as:                                              ]8;id=856550;file://C:\Users\cooba\Desktop\SUML_praca_koncowa\SUML_projekt\venv\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=878532;file://C:\Users\cooba\Desktop\SUML_praca_koncowa\SUML_projekt\venv\Lib\site-packages\kedro\ipython\__init__.py#181\181]8;;\
#                              C:\Users\cooba\Desktop\SUML_praca_koncowa\SUML_projekt.
#                              To set a different path, run '%reload_kedro <project_root>'
# ...

# %%
df = catalog.load("X_train")
# Out:
#                     INFO     Loading data from X_train (CSVDataset)...                         ]8;id=162371;file://C:\Users\cooba\Desktop\SUML_praca_koncowa\SUML_projekt\venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=242094;file://C:\Users\cooba\Desktop\SUML_praca_koncowa\SUML_projekt\venv\Lib\site-packages\kedro\io\data_catalog.py#1048\1048]8;;\

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
df.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    Location   MinTemp   MaxTemp  Rainfall  WindGustDir  WindGustSpeed  \
# 0        20  1.777948  2.695676 -0.329710            7       0.568059
# 1        41 -1.429450 -0.457816 -0.004595            1      -0.626403
# 2        27  1.292927  0.313037 -0.040719            3       3.940658
# 3        27  1.105177  0.383115 -0.329710            1      -0.345353
# 4        37 -0.537637 -0.682065  0.230210           13      -0.204828
#
#    WindDir9am  WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# 0           9          15     -0.602105     -1.441779    -2.168489
# 1           8           1     -0.383535     -0.455962     0.103094
# 2           0           1      2.676446      3.596838     1.076629
# 3           5           5     -0.164965      0.091713    -0.600015
# 4          14           2     -0.164965      1.187065     1.292970
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44627 entries, 0 to 44626
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Location         44627 non-null  int64
#  1   MinTemp          44627 non-null  float64
#  2   MaxTemp          44627 non-null  float64
#  3   Rainfall         44627 non-null  float64
#  4   WindGustDir      44627 non-null  int64
#  5   WindGustSpeed    44627 non-null  float64
#  6   WindDir9am       44627 non-null  int64
#  7   WindDir3pm       44627 non-null  int64
#  8   WindSpeed9am     44627 non-null  float64
#  9   WindSpeed3pm     44627 non-null  float64
#  10  Humidity9am      44627 non-null  float64
#  11  Humidity3pm      44627 non-null  float64
#  12  Pressure9am      44627 non-null  float64
#  13  Pressure3pm      44627 non-null  float64
#  14  Temp9am          44627 non-null  float64
#  15  Temp3pm          44627 non-null  float64
# ...
