# %%
# %load_ext kedro.ipython
# %reload_kedro
# Out:
# The kedro.ipython extension is already loaded. To reload it, use:
#   %reload_ext kedro.ipython
# [01/17/26 16:41:23] INFO     Resolved project path as:                                              ]8;id=878976;file://C:\Users\cooba\Desktop\SUML_praca_koncowa\SUML_projekt\venv\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=35217;file://C:\Users\cooba\Desktop\SUML_praca_koncowa\SUML_projekt\venv\Lib\site-packages\kedro\ipython\__init__.py#181\181]8;;\
#                              C:\Users\cooba\Desktop\SUML_praca_koncowa\SUML_projekt.
#                              To set a different path, run '%reload_kedro <project_root>'
# ...
