# %%
# %load_ext kedro.ipython
# %reload_kedro
# Out:
# The kedro.ipython extension is already loaded. To reload it, use:
#   %reload_ext kedro.ipython
#                     INFO     Resolved project path as:                                              ]8;id=237589;file://C:\Users\cooba\Desktop\SUML_praca_koncowa\SUML_projekt\venv\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=586971;file://C:\Users\cooba\Desktop\SUML_praca_koncowa\SUML_projekt\venv\Lib\site-packages\kedro\ipython\__init__.py#181\181]8;;\
#                              C:\Users\cooba\Desktop\SUML_praca_koncowa\SUML_projekt.
#                              To set a different path, run '%reload_kedro <project_root>'
# ...

# %%
df = catalog.load("raw_data")
# Out:
#                     INFO     Loading data from raw_data (CSVDataset)...                        ]8;id=716945;file://C:\Users\cooba\Desktop\SUML_praca_koncowa\SUML_projekt\venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=671328;file://C:\Users\cooba\Desktop\SUML_praca_koncowa\SUML_projekt\venv\Lib\site-packages\kedro\io\data_catalog.py#1048\1048]8;;\

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
df.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  \
# 0           W           44.0          W        WNW          20.0
# 1         WNW           44.0        NNW        WSW           4.0
# 2         WSW           46.0          W        WSW          19.0
# 3          NE           24.0         SE          E          11.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
df.notna().mean() * 100
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Date             100.000000
# Location         100.000000
# MinTemp           98.979101
# MaxTemp           99.133095
# Rainfall          97.758147
# Evaporation       56.833494
# Sunshine          51.990238
# WindGustDir       92.901141
# WindGustSpeed     92.944452
# WindDir9am        92.736147
# WindDir3pm        97.093359
# WindSpeed9am      98.785233
# WindSpeed3pm      97.894954
# Humidity9am       98.175443
# Humidity3pm       96.901554
# Pressure9am       89.643201
# Pressure3pm       89.668637
# Cloud9am          61.578441
# Cloud3pm          59.192905
# Temp9am           98.785233
# Temp3pm           97.518906
# RainToday         97.758147
# RainTomorrow      97.754022
# dtype: float64
